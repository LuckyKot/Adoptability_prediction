# %%
import matplotlib.pyplot as plt
import matplotlib.lines as lines
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import root_mean_squared_error

# %matplotlib inline

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, precision_score

plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})

# %%
data = pd.read_csv("data_impute_encoded.csv")

# %%
data
# Out:
#                Age  Adopted   BIRD    CAT    DOG  LIVESTOCK  OTHER  APRICOT  \
# 0      5475.000000    False  False  False   True      False  False    False
# 1      6570.000000    False  False  False   True      False  False    False
# 2      6570.000000    False  False  False   True      False  False    False
# 3      5840.000000    False  False   True  False      False  False    False
# 4      6205.000000    False  False  False   True      False  False    False
# ...            ...      ...    ...    ...    ...        ...    ...      ...
# 17176  1095.000000    False  False  False   True      False  False    False
# 17177   150.000000    False  False   True  False      False  False    False
# 17178   150.000000     True  False   True  False      False  False    False
# 17179   150.000000    False  False   True  False      False  False    False
# 17180   773.240288    False  False  False   True      False  False    False
#
#        BEIGE  BLACK  ...  MILPITAS  MONTE SERENO  MORGAN HILL  MOUNTAIN VIEW  \
# 0      False  False  ...     False         False        False          False
# 1      False  False  ...     False         False        False          False
# 2      False  False  ...     False         False        False          False
# 3      False  False  ...     False         False        False          False
# 4      False  False  ...     False         False        False          False
# ...      ...    ...  ...       ...           ...          ...            ...
# 17176  False   True  ...     False         False        False          False
# 17177  False  False  ...     False         False        False          False
# 17178  False  False  ...     False         False        False          False
# 17179  False  False  ...     False         False        False          False
# 17180  False  False  ...     False         False        False          False
#
#        OUT OF COUNTY  PALO ALTO  SAN JOSE  SANTA CLARA  SARATOGA  SUNNYVALE
# 0              False      False      True        False     False      False
# 1              False      False      True        False     False      False
# 2              False      False      True        False     False      False
# 3              False      False      True        False     False      False
# 4              False      False      True        False     False      False
# ...              ...        ...       ...          ...       ...        ...
# 17176          False      False      True        False     False      False
# 17177          False      False      True        False     False      False
# 17178          False      False      True        False     False      False
# 17179          False      False      True        False     False      False
# 17180          False      False      True        False     False      False
#
# [17181 rows x 404 columns]

# %%
y = data.Adopted

# %%
x = data.drop(columns=["Adopted"])

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, shuffle=True, test_size=.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
KNN = KNeighborsClassifier(n_neighbors=20)
KNN.fit(x_train, y_train)
KNN_pred = KNN.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, KNN_pred))
disp.plot()

# %%
error_rate=[]

for i in range(1,100):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    pred=knn.predict(x_test)
    error_rate.append(np.mean(pred != y_test))
    
plt.figure(figsize=(10,5))
plt.plot(range(1,100),error_rate,marker='o',markersize=9)
print("K needs to be {}, with obtained minimum error {}".format(error_rate.index(min(error_rate))+1,min(error_rate)))
# Out:
# K needs to be 27, with obtained minimum error 0.18737270875763748

# %%
KNN = KNeighborsClassifier(n_neighbors=27)
KNN.fit(x_train, y_train)
KNN_pred = KNN.predict(x_test)
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, KNN_pred))
disp.plot()

# %%
RF = RandomForestClassifier(n_estimators=200)
RF.fit(x_train, y_train)
RF_pred = RF.predict(x_test)
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, RF_pred))
disp.plot()

# %%
error_rate=[]

for i in range(25,1000,25):
    RF = RandomForestClassifier(n_estimators=i)
    RF.fit(x_train, y_train)
    pred=RF.predict(x_test)
    error_rate.append(np.mean(pred != y_test))
    
plt.figure(figsize=(10,5))
plt.plot(range(1,40),error_rate,marker='o',markersize=9)
print("K needs to be {}, with obtained minimum error {}".format(error_rate.index(min(error_rate))+1,min(error_rate)))
# Out:
# K needs to be 3, with obtained minimum error 0.17980797206866453

# %%
RF = RandomForestClassifier(n_estimators=100)
RF.fit(x_train, y_train)
RF_pred = RF.predict(x_test)
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, RF_pred))
disp.plot()

# %%
SVM = SVC(C=10, gamma=0.1)
SVM.fit(x_train, y_train)
svm_pred = SVM.predict(x_test)
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, svm_pred))
disp.plot()

# %%
from sklearn.model_selection import GridSearchCV 
  
# defining parameter range 
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3) 

grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.736 total time= 1.6min
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.738 total time= 1.6min
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.736 total time= 1.6min
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.736 total time= 1.5min
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.737 total time= 1.7min
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.774 total time=  44.2s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.774 total time=  43.2s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.773 total time=  43.8s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.766 total time=  43.4s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.779 total time=  45.1s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.745 total time=  41.8s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.742 total time=  40.7s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.738 total time=  40.1s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.743 total time=  41.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.737 total time=  41.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.741 total time=  37.9s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.740 total time=  37.4s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.738 total time=  37.5s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.743 total time=  37.5s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.737 total time=  38.6s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.741 total time=  36.3s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.740 total time=  36.9s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.737 total time=  37.3s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.742 total time=  37.1s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.741 total time=  37.2s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.778 total time= 1.6min
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.781 total time= 1.5min
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.767 total time= 1.5min
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.769 total time= 1.5min
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.779 total time= 1.5min
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.825 total time=  38.4s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.818 total time=  38.7s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.807 total time=  37.7s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.833 total time=  38.1s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.825 total time=  38.5s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.795 total time=  39.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.792 total time=  39.4s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.792 total time=  39.2s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.793 total time=  38.9s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.804 total time=  39.6s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.740 total time=  38.6s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.740 total time=  37.6s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.738 total time=  37.5s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.744 total time=  38.4s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.737 total time=  38.2s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.741 total time=  37.2s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.741 total time=  37.7s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.737 total time=  38.1s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.742 total time=  37.8s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.741 total time=  38.5s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.780 total time= 2.2min
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.784 total time= 2.2min
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.772 total time= 2.2min
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.776 total time= 2.3min
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.785 total time= 2.3min
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.824 total time=  35.9s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.809 total time=  35.8s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.805 total time=  34.9s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.828 total time=  35.5s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.829 total time=  35.6s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.828 total time=  34.3s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.824 total time=  34.3s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.808 total time=  33.6s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.826 total time=  34.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.827 total time=  34.5s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.823 total time=  36.4s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.804 total time=  36.2s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.804 total time=  36.3s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.820 total time=  35.9s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.825 total time=  36.8s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.780 total time=  38.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.762 total time=  38.5s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.774 total time=  38.2s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.766 total time=  37.9s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.763 total time=  38.8s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.780 total time= 2.2min
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.784 total time= 2.2min
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.772 total time= 2.2min
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.776 total time= 2.2min
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.785 total time= 2.3min
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.822 total time=  35.9s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.802 total time=  35.6s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.810 total time=  35.1s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.816 total time=  36.3s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.819 total time=  35.9s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.820 total time=  33.1s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.813 total time=  32.7s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.805 total time=  31.4s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.823 total time=  33.1s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.828 total time=  32.5s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.826 total time=  31.4s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.822 total time=  30.8s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.813 total time=  31.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.826 total time=  31.3s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.829 total time=  31.6s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.826 total time=  34.7s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.817 total time=  34.9s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.812 total time=  34.4s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.825 total time=  34.6s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.832 total time=  35.5s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.780 total time= 2.3min
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.784 total time= 2.2min
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.772 total time= 2.3min
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.776 total time= 2.2min
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.785 total time= 2.3min
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.822 total time=  35.7s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.802 total time=  35.2s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.810 total time=  35.9s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.817 total time=  36.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.819 total time=  36.1s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.817 total time=  38.1s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.805 total time=  35.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.805 total time=  34.1s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.817 total time=  36.4s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.817 total time=  36.1s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.820 total time=  30.4s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.810 total time=  30.7s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.804 total time=  31.1s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.818 total time=  30.5s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.824 total time=  31.2s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.827 total time=  34.5s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.826 total time=  33.5s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.815 total time=  32.8s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.824 total time=  34.9s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.831 total time=  34.8s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
SVM = SVC(C=1000, gamma=0.0001)
SVM.fit(x_train, y_train)
svm_pred = SVM.predict(x_test)
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, svm_pred))
disp.plot()

# %%
# accuracy
