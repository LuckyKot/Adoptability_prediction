# %%
import matplotlib.pyplot as plt
import matplotlib.lines as lines
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import root_mean_squared_error

# %matplotlib inline

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, precision_score

plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})

# %%
data = pd.read_csv("data_impute_encoded.csv")

# %%
y = data.Adopted

# %%
x = data.drop(columns=["Adopted"])

# %%
import torch
 
X_nn = torch.tensor(x.values.astype(np.float32), dtype=torch.float32)
y_nn = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
X_nn.shape
# Out:
# torch.Size([17181, 403])

# %%
import torch.nn as nn

class AdoptionModel(nn.Module):
    def __init__(self,dims):
        super().__init__()
        self.hidden = nn.Linear(dims, dims)
        self.relu = nn.ReLU()
        self.hidden2 = nn.Linear(dims, dims)
        self.hidden3 = nn.Linear(dims, dims//2)
        self.hidden4 = nn.Linear(dims//2, dims//4)
        self.hidden5 = nn.Linear(dims//4, dims//8)
        self.output = nn.Linear(dims//8, 1)
        self.dropout = nn.Dropout(0.5)
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, x):
        x = self.dropout(self.relu(self.hidden(x)))
        x = self.dropout(self.relu(self.hidden2(x)))
        x = self.dropout(self.relu(self.hidden3(x)))
        x = self.relu(self.hidden4(x))
        x = self.relu(self.hidden5(x))
        x = self.sigmoid(self.output(x))
        
        return x

# %%
model = AdoptionModel(X_nn.shape[1])

# %%
x_train, x_test, y_train, y_test= train_test_split(X_nn, y_nn, shuffle=True, test_size=.2)

# %%
import torch.optim as optim
loss_fn = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import torch
import torch.nn as nn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib
import matplotlib.pyplot as plt
import time
import os
import copy
import random
import warnings
import shutil

train_data = []
for i in range(len(x_train)):
    train_data.append([x_train[i], y_train[i]])

trainloader = torch.utils.data.DataLoader(train_data, shuffle=True, batch_size=128)

test_data = []
for i in range(len(x_test)):
   test_data.append([x_test[i], y_test[i]])

testloader = torch.utils.data.DataLoader(test_data, shuffle=True, batch_size=128)

dataloaders={}
dataloaders['train']=trainloader
dataloaders['val']=testloader

dataset_sizes={}
dataset_sizes['train']=x_train.shape[0]
dataset_sizes['val']=x_test.shape[0]
 
def train_model(model, dataloaders, dataset_sizes, criterion, optimizer, start_epoch=0, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    train_loss = [0.0 for i in range(0, num_epochs)] #start_epoch
    val_loss = [0.0 for i in range(0, num_epochs)]
    train_acc = [0.0 for i in range(0, num_epochs)]
    val_acc = [0.0 for i in range(0, num_epochs)]

    for epoch in range(start_epoch, num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)


        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            end = time.time()
            # Iterate over data.
            for i, (inputs, labels) in enumerate(dataloaders[phase]):
                # zero the parameter gradients, clear the gradients of all optimized variables
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs) 
                    
                    if type(outputs) is tuple: #model may output multiple tensors as tuple
                        outputs, _ = outputs

                    # calculate the batch loss
                    loss = criterion(outputs, labels)


                    # backward + optimize only if in training phase
                    if phase == 'train':
                        # backward pass: compute gradient of the loss with respect to model parameters
                        loss.backward()
                        # perform a single optimization step (parameter update)
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)#batch size
                for i in range(len(outputs)):
                    if outputs[i]>=.5:
                        if labels[i]==1:
                            running_corrects+=1
                    else:
                        if labels[i]==0:
                            running_corrects+=1
        
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            if phase == 'train':
                train_loss[epoch] = epoch_loss
                train_acc[epoch] = epoch_acc
            else:
                val_loss[epoch] = epoch_loss
                val_acc[epoch] = epoch_acc
                
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
            

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    plt.figure(figsize=(10,5))
    plt.title("Loss graph")
    plt.plot(range(0,num_epochs),train_loss)
    plt.plot(range(0,num_epochs),val_loss)
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(['train','validation'])
    plt.show()

    plt.title("Accuracy graph")
    plt.plot(range(0,num_epochs),train_acc)
    plt.plot(range(0,num_epochs),val_acc)
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(['train','validation'])
    plt.show()
    
    return model
# Out:
# D:\conda\Lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
train_model(model, dataloaders, dataset_sizes, loss_fn, optimizer, start_epoch=0, num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.6165 Acc: 0.7264
# val Loss: 0.6084 Acc: 0.7384
# Epoch 1/99
# ----------
# train Loss: 0.5961 Acc: 0.7324
# val Loss: 0.5811 Acc: 0.7384
# Epoch 2/99
# ----------
# train Loss: 0.5563 Acc: 0.7324
# val Loss: 0.5810 Acc: 0.7384
# Epoch 3/99
# ----------
# train Loss: 0.4866 Acc: 0.7324
# val Loss: 0.4567 Acc: 0.7384
# Epoch 4/99
# ----------
# train Loss: 0.4321 Acc: 0.7384
# val Loss: 0.3797 Acc: 0.7969
# Epoch 5/99
# ----------
# train Loss: 0.4293 Acc: 0.7869
# val Loss: 0.3716 Acc: 0.8019
# Epoch 6/99
# ----------
# train Loss: 0.3942 Acc: 0.8014
# val Loss: 0.4019 Acc: 0.7867
# Epoch 7/99
# ----------
# train Loss: 0.4103 Acc: 0.7926
# val Loss: 0.3673 Acc: 0.8094
# Epoch 8/99
# ----------
# train Loss: 0.4283 Acc: 0.7760
# val Loss: 0.4068 Acc: 0.7684
# Epoch 9/99
# ----------
# train Loss: 0.4123 Acc: 0.7823
# val Loss: 0.3878 Acc: 0.7981
# Epoch 10/99
# ----------
# train Loss: 0.4298 Acc: 0.7705
# val Loss: 0.4547 Acc: 0.7544
# Epoch 11/99
# ----------
# train Loss: 0.4443 Acc: 0.7536
# val Loss: 0.4097 Acc: 0.7771
# Epoch 12/99
# ----------
# train Loss: 0.4314 Acc: 0.7639
# val Loss: 0.3668 Acc: 0.8056
# Epoch 13/99
# ----------
# train Loss: 0.4055 Acc: 0.7678
# val Loss: 0.3614 Acc: 0.8065
# Epoch 14/99
# ----------
# train Loss: 0.4066 Acc: 0.7742
# val Loss: 0.3547 Acc: 0.8132
# Epoch 15/99
# ----------
# train Loss: 0.4074 Acc: 0.7725
# val Loss: 0.3587 Acc: 0.7966
# Epoch 16/99
# ----------
# train Loss: 0.4086 Acc: 0.7717
# val Loss: 0.3644 Acc: 0.8155
# Epoch 17/99
# ----------
# train Loss: 0.4067 Acc: 0.7737
# val Loss: 0.3626 Acc: 0.8088
# Epoch 18/99
# ----------
# train Loss: 0.4088 Acc: 0.7761
# val Loss: 0.3652 Acc: 0.7995
# Epoch 19/99
# ----------
# train Loss: 0.4121 Acc: 0.7663
# val Loss: 0.3679 Acc: 0.7984
# Epoch 20/99
# ----------
# train Loss: 0.4116 Acc: 0.7731
# val Loss: 0.3927 Acc: 0.8164
# Epoch 21/99
# ----------
# train Loss: 0.3987 Acc: 0.7704
# val Loss: 0.3579 Acc: 0.8155
# Epoch 22/99
# ----------
# train Loss: 0.4020 Acc: 0.7704
# val Loss: 0.3534 Acc: 0.8007
# Epoch 23/99
# ----------
# train Loss: 0.4014 Acc: 0.7726
# val Loss: 0.3591 Acc: 0.8147
# Epoch 77/99
# ----------
# train Loss: 0.3678 Acc: 0.7940
# val Loss: 0.3560 Acc: 0.8120
# Epoch 78/99
# ----------
# train Loss: 0.3674 Acc: 0.7910
# val Loss: 0.3643 Acc: 0.8123
# Epoch 79/99
# ----------
# train Loss: 0.3740 Acc: 0.7876
# val Loss: 0.3546 Acc: 0.8033
# Epoch 80/99
# ----------
# train Loss: 0.3699 Acc: 0.7939
# val Loss: 0.3588 Acc: 0.8097
# Epoch 81/99
# ----------
# train Loss: 0.3749 Acc: 0.7872
# val Loss: 0.3535 Acc: 0.8103
# Epoch 82/99
# ----------
# train Loss: 0.3639 Acc: 0.8042
# val Loss: 0.3519 Acc: 0.8077
# Epoch 83/99
# ----------
# train Loss: 0.3679 Acc: 0.7937
# val Loss: 0.3525 Acc: 0.8126
# Epoch 84/99
# ----------
# train Loss: 0.3747 Acc: 0.7869
# val Loss: 0.3522 Acc: 0.8158
# Epoch 85/99
# ----------
# train Loss: 0.3759 Acc: 0.7849
# val Loss: 0.3675 Acc: 0.8129
# Epoch 86/99
# ----------
# train Loss: 0.3759 Acc: 0.7814
# val Loss: 0.3524 Acc: 0.8126
# Epoch 87/99
# ----------
# train Loss: 0.3661 Acc: 0.7985
# val Loss: 0.3600 Acc: 0.8135
# Epoch 88/99
# ----------
# train Loss: 0.3717 Acc: 0.7959
# val Loss: 0.3558 Acc: 0.8126
# Epoch 89/99
# ----------
# train Loss: 0.3649 Acc: 0.8067
# val Loss: 0.3536 Acc: 0.8155
# Epoch 90/99
# ----------
# train Loss: 0.3776 Acc: 0.7890
# val Loss: 0.3468 Acc: 0.8193
# Epoch 91/99
# ----------
# train Loss: 0.3651 Acc: 0.7936
# val Loss: 0.3583 Acc: 0.7882
# Epoch 92/99
# ----------
# train Loss: 0.3694 Acc: 0.7875
# val Loss: 0.3590 Acc: 0.8118
# Epoch 93/99
# ----------
# train Loss: 0.3722 Acc: 0.7975
# val Loss: 0.3746 Acc: 0.8051
# Epoch 94/99
# ----------
# train Loss: 0.3686 Acc: 0.7919
# val Loss: 0.3499 Acc: 0.8094
# Epoch 95/99
# ----------
# train Loss: 0.3655 Acc: 0.8018
# val Loss: 0.3733 Acc: 0.8048
# Epoch 96/99
# ----------
# train Loss: 0.3709 Acc: 0.7899
# val Loss: 0.3597 Acc: 0.8097
# Epoch 97/99
# ----------
# train Loss: 0.3679 Acc: 0.7945
# val Loss: 0.3757 Acc: 0.7987
# Epoch 98/99
# ----------
# train Loss: 0.3662 Acc: 0.7974
# val Loss: 0.3593 Acc: 0.8109
# Epoch 99/99
# ----------
# train Loss: 0.3587 Acc: 0.8038
# val Loss: 0.3647 Acc: 0.8059
# Training complete in 2m 0s
# Best val Acc: 0.819319
# AdoptionModel(
#   (hidden): Linear(in_features=403, out_features=403, bias=True)
#   (relu): ReLU()
#   (hidden2): Linear(in_features=403, out_features=403, bias=True)
#   (hidden3): Linear(in_features=403, out_features=201, bias=True)
#   (hidden4): Linear(in_features=201, out_features=100, bias=True)
#   (hidden5): Linear(in_features=100, out_features=50, bias=True)
#   (output): Linear(in_features=50, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )
